# %%
import pandas as pd

# 불러오기
df = pd.read_parquet("cluster_trace_5min.parquet")
print(df.tail())
print(df.count())
print(df.dtypes)
print()
print(df.isnull().sum())
# Out:
#                timestamp   avg_cpu   avg_mem  avg_assigned_mem  \
# 8059 2024-01-28 23:35:00  0.504968  0.293404          0.551731
# 8060 2024-01-28 23:40:00  0.506363  0.298179          0.555410
# 8061 2024-01-28 23:45:00  0.499171  0.295727          0.555600
# 8062 2024-01-28 23:50:00  0.518006  0.301373          0.559500
# 8063 2024-01-28 23:55:00  0.521053  0.302963          0.562060
#
#       avg_cycles_per_instruction
# 8059                  181.323612
# 8060                  181.408185
# 8061                  179.183537
# 8062                  179.378914
# 8063                  179.542929
# timestamp                     8064
# avg_cpu                       8064
# avg_mem                       8064
# avg_assigned_mem              8064
# avg_cycles_per_instruction    8064
# dtype: int64
# timestamp                     datetime64[ns]
# avg_cpu                              float64
# avg_mem                              float64
# avg_assigned_mem                     float64
# ...
